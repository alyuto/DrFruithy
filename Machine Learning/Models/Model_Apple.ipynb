# %%
pip install keras-preprocessing
# Out:
# Collecting keras-preprocessing
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-preprocessing) (1.25.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras-preprocessing) (1.16.0)
# Installing collected packages: keras-preprocessing
# Successfully installed keras-preprocessing-1.1.2

# %% [markdown]
# #Setup

# %%
import numpy as np
import os
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from keras_preprocessing.image import ImageDataGenerator
import albumentations as A
from collections import Counter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
training_dir = '/content/drive/MyDrive/Dataset Dr.Fruithy/Apple'

# %% [markdown]
# #Data Augmentation

# %%
training_datagen = ImageDataGenerator(
    rescale=1/255., zoom_range=0.2, shear_range=0.2,
    rotation_range=20, horizontal_flip=True, validation_split=0.2
)
train_generator = training_datagen.flow_from_directory(
    training_dir, target_size=(150,150), color_mode='rgb', class_mode='categorical', subset='training'
)

validation_generator = training_datagen.flow_from_directory(
    training_dir, target_size=(150,150), color_mode='rgb', class_mode='categorical', subset='validation'
)
# Out:
# Found 4685 images belonging to 10 classes.
# Found 1166 images belonging to 10 classes.

# %% [markdown]
# #Model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %% [markdown]
# #Training

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_generator, steps_per_epoch=80, validation_data=validation_generator,
          validation_steps=20, epochs=50)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 2087s 26s/step - loss: 2.0028 - accuracy: 0.4098 - val_loss: 1.6388 - val_accuracy: 0.4172
# Epoch 2/50
# 80/80 [==============================] - 859s 11s/step - loss: 1.3958 - accuracy: 0.5116 - val_loss: 1.6289 - val_accuracy: 0.4641
# Epoch 3/50
# 80/80 [==============================] - 397s 5s/step - loss: 1.3364 - accuracy: 0.5325 - val_loss: 1.4484 - val_accuracy: 0.5016
# Epoch 4/50
# 80/80 [==============================] - 196s 2s/step - loss: 1.2971 - accuracy: 0.5555 - val_loss: 1.5319 - val_accuracy: 0.4797
# Epoch 5/50
# 80/80 [==============================] - 106s 1s/step - loss: 1.2112 - accuracy: 0.5880 - val_loss: 1.4904 - val_accuracy: 0.5078
# Epoch 6/50
# 80/80 [==============================] - 68s 856ms/step - loss: 1.1786 - accuracy: 0.5707 - val_loss: 1.6188 - val_accuracy: 0.4203
# Epoch 7/50
# 80/80 [==============================] - 49s 603ms/step - loss: 1.1351 - accuracy: 0.6047 - val_loss: 1.6723 - val_accuracy: 0.3953
# Epoch 8/50
# 80/80 [==============================] - 40s 488ms/step - loss: 1.0960 - accuracy: 0.6183 - val_loss: 1.5892 - val_accuracy: 0.4422
# Epoch 9/50
# 80/80 [==============================] - 39s 493ms/step - loss: 1.0682 - accuracy: 0.6379 - val_loss: 1.6499 - val_accuracy: 0.4516
# Epoch 10/50
# 80/80 [==============================] - 36s 454ms/step - loss: 1.0218 - accuracy: 0.6352 - val_loss: 1.4893 - val_accuracy: 0.4625
# Epoch 11/50
# 80/80 [==============================] - 36s 448ms/step - loss: 0.9954 - accuracy: 0.6556 - val_loss: 1.8206 - val_accuracy: 0.3906
# Epoch 12/50
# 80/80 [==============================] - 35s 438ms/step - loss: 0.9411 - accuracy: 0.6613 - val_loss: 1.6550 - val_accuracy: 0.4578
# Epoch 13/50
# 80/80 [==============================] - 40s 498ms/step - loss: 0.9196 - accuracy: 0.6765 - val_loss: 1.8357 - val_accuracy: 0.4656
# Epoch 14/50
# 80/80 [==============================] - 39s 483ms/step - loss: 0.9247 - accuracy: 0.6773 - val_loss: 1.7149 - val_accuracy: 0.4281
# Epoch 15/50
# 80/80 [==============================] - 38s 478ms/step - loss: 0.8597 - accuracy: 0.6997 - val_loss: 1.6086 - val_accuracy: 0.4828
# Epoch 16/50
# 80/80 [==============================] - 37s 468ms/step - loss: 0.8591 - accuracy: 0.7060 - val_loss: 1.6514 - val_accuracy: 0.4531
# Epoch 17/50
# 80/80 [==============================] - 34s 431ms/step - loss: 0.8594 - accuracy: 0.7000 - val_loss: 1.8387 - val_accuracy: 0.4563
# Epoch 18/50
# 80/80 [==============================] - 37s 464ms/step - loss: 0.8166 - accuracy: 0.7141 - val_loss: 1.7390 - val_accuracy: 0.4891
# Epoch 19/50
# 80/80 [==============================] - 38s 476ms/step - loss: 0.7622 - accuracy: 0.7430 - val_loss: 1.6931 - val_accuracy: 0.4422
# Epoch 20/50
# 80/80 [==============================] - 37s 469ms/step - loss: 0.7089 - accuracy: 0.7540 - val_loss: 1.6625 - val_accuracy: 0.5297
# Epoch 21/50
# 80/80 [==============================] - 39s 485ms/step - loss: 0.7208 - accuracy: 0.7512 - val_loss: 1.7632 - val_accuracy: 0.4563
# Epoch 22/50
# 80/80 [==============================] - 36s 454ms/step - loss: 0.7225 - accuracy: 0.7465 - val_loss: 1.6873 - val_accuracy: 0.5234
# Epoch 23/50
# 80/80 [==============================] - 39s 491ms/step - loss: 0.7006 - accuracy: 0.7563 - val_loss: 1.7798 - val_accuracy: 0.4953
# Epoch 24/50
# 80/80 [==============================] - 35s 443ms/step - loss: 0.6389 - accuracy: 0.7676 - val_loss: 1.8838 - val_accuracy: 0.4875
# Epoch 25/50
# 80/80 [==============================] - 35s 440ms/step - loss: 0.6516 - accuracy: 0.7715 - val_loss: 1.8644 - val_accuracy: 0.4469
# Epoch 26/50
# 80/80 [==============================] - 36s 452ms/step - loss: 0.6758 - accuracy: 0.7688 - val_loss: 1.8022 - val_accuracy: 0.4641
# Epoch 27/50
# 80/80 [==============================] - 35s 437ms/step - loss: 0.6208 - accuracy: 0.7753 - val_loss: 1.7980 - val_accuracy: 0.5078
# Epoch 28/50
# 80/80 [==============================] - 38s 479ms/step - loss: 0.6263 - accuracy: 0.7703 - val_loss: 2.0390 - val_accuracy: 0.4437
# Epoch 29/50
# 80/80 [==============================] - 36s 448ms/step - loss: 0.5594 - accuracy: 0.7910 - val_loss: 2.0208 - val_accuracy: 0.4531
# Epoch 30/50
# 80/80 [==============================] - 39s 488ms/step - loss: 0.6157 - accuracy: 0.7805 - val_loss: 1.7807 - val_accuracy: 0.4828
# Epoch 31/50
# 80/80 [==============================] - 38s 476ms/step - loss: 0.5785 - accuracy: 0.7973 - val_loss: 1.8765 - val_accuracy: 0.5109
# Epoch 32/50
# 80/80 [==============================] - 35s 444ms/step - loss: 0.5652 - accuracy: 0.7930 - val_loss: 1.9451 - val_accuracy: 0.5031
# Epoch 33/50
# 80/80 [==============================] - 38s 479ms/step - loss: 0.5895 - accuracy: 0.7914 - val_loss: 1.8604 - val_accuracy: 0.4625
# Epoch 34/50
# 80/80 [==============================] - 35s 438ms/step - loss: 0.5251 - accuracy: 0.8125 - val_loss: 2.0069 - val_accuracy: 0.4625
# Epoch 35/50
# 80/80 [==============================] - 38s 476ms/step - loss: 0.4885 - accuracy: 0.8203 - val_loss: 1.7728 - val_accuracy: 0.5297
# Epoch 36/50
# 80/80 [==============================] - 38s 475ms/step - loss: 0.5007 - accuracy: 0.8139 - val_loss: 2.0383 - val_accuracy: 0.4859
# Epoch 37/50
# 80/80 [==============================] - 39s 490ms/step - loss: 0.4924 - accuracy: 0.8297 - val_loss: 2.0267 - val_accuracy: 0.4594
# Epoch 38/50
# 80/80 [==============================] - 38s 480ms/step - loss: 0.5067 - accuracy: 0.8229 - val_loss: 1.9808 - val_accuracy: 0.4812
# Epoch 39/50
# 80/80 [==============================] - 39s 482ms/step - loss: 0.4356 - accuracy: 0.8465 - val_loss: 1.8283 - val_accuracy: 0.5188
# Epoch 40/50
# 80/80 [==============================] - 37s 462ms/step - loss: 0.4378 - accuracy: 0.8418 - val_loss: 2.0200 - val_accuracy: 0.4531
# Epoch 41/50
# 80/80 [==============================] - 35s 437ms/step - loss: 0.4668 - accuracy: 0.8301 - val_loss: 1.9978 - val_accuracy: 0.5406
# Epoch 42/50
# 80/80 [==============================] - 38s 479ms/step - loss: 0.4252 - accuracy: 0.8422 - val_loss: 2.0581 - val_accuracy: 0.4922
# Epoch 43/50
# 80/80 [==============================] - 38s 482ms/step - loss: 0.4126 - accuracy: 0.8516 - val_loss: 2.0772 - val_accuracy: 0.5094
# Epoch 44/50
# 80/80 [==============================] - 36s 453ms/step - loss: 0.4123 - accuracy: 0.8520 - val_loss: 1.8912 - val_accuracy: 0.5422
# Epoch 45/50
# 80/80 [==============================] - 41s 520ms/step - loss: 0.3821 - accuracy: 0.8674 - val_loss: 2.0032 - val_accuracy: 0.4609
# Epoch 46/50
# 80/80 [==============================] - 38s 477ms/step - loss: 0.3835 - accuracy: 0.8564 - val_loss: 2.0503 - val_accuracy: 0.5031
# Epoch 47/50
# 80/80 [==============================] - 36s 448ms/step - loss: 0.3695 - accuracy: 0.8717 - val_loss: 2.2279 - val_accuracy: 0.5281
# Epoch 48/50
# 80/80 [==============================] - 34s 429ms/step - loss: 0.3486 - accuracy: 0.8852 - val_loss: 2.1303 - val_accuracy: 0.5250
# Epoch 49/50
# 80/80 [==============================] - 38s 479ms/step - loss: 0.3667 - accuracy: 0.8660 - val_loss: 2.1672 - val_accuracy: 0.5125
# Epoch 50/50
# 80/80 [==============================] - 38s 471ms/step - loss: 0.3874 - accuracy: 0.8642 - val_loss: 2.0925 - val_accuracy: 0.5188

# %% [markdown]
# #Plot

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

#training and validation accuracy
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

#training dan validation loss
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# #Export
